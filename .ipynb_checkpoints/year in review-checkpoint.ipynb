# %%
import tmdbsimple as tmdb
import pandas as pd
import os

tmdb.API_KEY = '6c37d50741c7004f344af19bf3a67b10'

# Declare variable to use the Search and Discover function
search = tmdb.Search()
discover = tmdb.Discover()

# %%
#ultimate goal: is to create the prettiness of the letterboxd pro stats but 4 free

# %%
#whose folder do we go into
name = 'tory'
os.chdir(r'd:\projects\letterbox')
os.chdir(name)
cwd = os.getcwd()
cwd
# Out:
# 'd:\\projects\\letterbox\\tory'

# %%
diary = pd.read_csv("diary.csv")
watched_df = pd.read_csv ("watched.csv")
watched_df = watched_df.rename(columns={'release year': 'release'})

os.chdir('lists')
#tory: oh-look-its-my-personality
#charlie: films-i-enjoy-and-like.csv
length = len(pd.read_csv("oh-look-its-my-personality.csv"))
faves = pd.read_csv("oh-look-its-my-personality.csv", skiprows = 3, nrows=(length))

cwd
# Out:
# 'd:\\projects\\letterbox\\tory'

# %%
#change this for what you want
year = 2022
#set to true if you want a particular month
use_month = False
#set to month number
month = 0

# %%
watched_df
# Out:
#             Date                       Name  Year        Letterboxd URI
# 0     2022-09-30                   Megamind  2010  https://boxd.it/16Sk
# 1     2022-09-30       (500) Days of Summer  2009  https://boxd.it/1EmM
# 2     2022-09-30               The Proposal  2009  https://boxd.it/1HiS
# 3     2022-09-30                         Up  2009  https://boxd.it/1OEc
# 4     2022-09-30                 Wild Child  2008  https://boxd.it/1P0C
# ...          ...                        ...   ...                   ...
# 1316  2023-07-30                Oppenheimer  2023  https://boxd.it/wUow
# 1317  2023-07-31                     Barbie  2023  https://boxd.it/bCLK
# 1318  2023-08-01             The Bling Ring  2013  https://boxd.it/3lPY
# 1319  2023-08-02  How to Blow Up a Pipeline  2022  https://boxd.it/C69e
# 1320  2023-08-03         They Cloned Tyrone  2023  https://boxd.it/rE7a
#
# [1321 rows x 4 columns]

# %%
title = watched_df.Name.tolist()
released_year = watched_df.Year.tolist()

# %%
movie_id = [] # a variable to store a list of movies id
confirmed_movies = []

result_count=0
for i,j in zip(title,released_year):
    print(i)
    response = search.movie(query=i, year =j)
    for value in response['results']:
        if value['title'] == i:
            confirmed_movies.append(i);
            movie_id.append(value['id'])
            break 
    
confirmed_movies
# Out:
# Megamind
# (500) Days of Summer
# The Proposal
# Up
# Wild Child
# Alice in Wonderland
# Death Becomes Her
# Cloverfield
# The Addams Family
# Addams Family Values
# Bill & Ted's Bogus Journey
# Reservoir Dogs
# The Silence of the Lambs
# Pretty Woman
# Suspiria
# Steven Universe: The Movie
# The Knight Before Christmas
# The Queen's Gambit
# Moon Knight
# Dark Shadows
# Monte Carlo
# Paul
# TRON: Legacy
# Fired Up!
# Yes Man
# Dazed and Confused
# The Nightmare Before Christmas
# Twilight
# The Lion King
# Four Weddings and a Funeral
# Pulp Fiction
# Interview with the Vampire
# The Shawshank Redemption
# Groundhog Day
# Blended
# Thor: Love and Thunder
# Spider-Man: No Way Home
# Ms. Marvel
# She-Hulk: Attorney at Law
# Frankenweenie
# Whip It
# Jennifer's Body
# Zombieland
# The Boat That Rocked
# Shutter Island
# The Birdcage
# The Cable Guy
# Babylon
# The Beach Bum
# Sugar & Spice
# Barbie Video Game Hero
# Zoom
# Breakfast at Tiffany's
# Uptown Girls
# Calamity Jane
# The Vampire Lovers
# Pickle Surprise
# Wendell & Wild
# Fantastic Four
# Anaconda
# Badlands
# Franz Kafka's a Country Doctor
# Tour de Pharmacy
# Best in Show
# Morgan
# The Fairly OddParents! Abra Catastrophe
# The Wild Thornberrys Movie
# Never Rarely Sometimes Always
# Ali Wong: Don Wong
# Bad Education
# To Wong Foo, Thanks for Everything! Julie Newmar
# In the Loop
# Earth Girls Are Easy
# Bottle Rocket
# Batman & Robin
# Barbarella
# The Social Network
# The Muppets
# Female Trouble
# Saved!
# All Cheerleaders Die
# A League of Their Own
# War on Everyone
# Secretary
# Big Little Lies
# Home Again
# She-Devil
# Léon: The Professional
# The Super Mario Bros. Movie
# The Amazing Spider-Man 2
# Party Monster
# Batman Returns
# Big Fat Liar
# Two Heads Are Better Than None
# Pride & Prejudice
# A Perfect Getaway
# How to Lose a Guy in 10 Days
# Fried Green Tomatoes
# Nine to Five
# Steel Magnolias
# Maniac
# Zola
# Ready or Not
# Hustlers
# The Other Woman
# House of Gucci
# Dungeons & Dragons: Honor Among Thieves
# The Last Days of Disco
# Constantine
# D.E.B.S.
# Spider-Man: Across the Spider-Verse
# The Book of Life
# Trigun: Badlands Rumble
# Dead Leaves
# Black Lagoon
# Baccano!
# Elfen Lied
# Renfield
# Punch-Drunk Love
# Daria in 'Is It Fall Yet?'
# It's a Boy Girl Thing
# Ace Ventura: Pet Detective
# Girl 6
# Nimona
# The Voices
# Hunt for the Wilderpeople
# The Handmaiden
# 65
# Sundown
# Us Again
# Daria in 'Is It College Yet?'
# Destino
# Far from the Tree
# Wolfwalkers
# Triple Frontier
# James Acaster: Repertoire
# The Stepford Wives
# Pan's Labyrinth
# Carnage
# Igby Goes Down
# Ice Princess
# mid90s
# My Favorite Shapes by Julio Torres
# Lars and the Real Girl
# World of Tomorrow
# Oppenheimer
# Barbie
# The Bling Ring
# How to Blow Up a Pipeline
# They Cloned Tyrone
# ['Megamind',
#  '(500) Days of Summer',
#  'The Proposal',
#  'Up',
#  'Wild Child',
#  'Alice in Wonderland',
#  'Death Becomes Her',
#  'Cloverfield',
#  'The Addams Family',
#  'Addams Family Values',
#  "Bill & Ted's Bogus Journey",
#  'Reservoir Dogs',
#  'The Silence of the Lambs',
#  'Pretty Woman',
#  'Suspiria',
#  'Steven Universe: The Movie',
#  'The Knight Before Christmas',
#  'Dark Shadows',
#  'Monte Carlo',
#  'Paul',
#  'TRON: Legacy',
#  'Fired Up!',
#  'Yes Man',
#  'Dazed and Confused',
#  'The Nightmare Before Christmas',
#  'Twilight',
#  'The Lion King',
#  'Four Weddings and a Funeral',
#  'Pulp Fiction',
#  'Interview with the Vampire',
#  'The Shawshank Redemption',
#  'Groundhog Day',
#  'Blended',
#  'Thor: Love and Thunder',
#  'Spider-Man: No Way Home',
#  'Frankenweenie',
#  'Whip It',
#  "Jennifer's Body",
#  'Zombieland',
#  'The Boat That Rocked',
#  'Shutter Island',
#  'The Birdcage',
#  'The Cable Guy',
#  'Clueless',
#  'The Craft',
#  'Sgt. Bilko',
#  'Tank Girl',
#  'Jumanji',
#  'Toy Story',
#  'Se7en',
#  'Trainspotting',
#  'Batman Forever',
#  'Fargo',
#  'Twelve Monkeys',
#  'John Mulaney & The Sack Lunch Bunch',
#  'Shiva Baby',
#  'The Fifth Element',
#  'Rango',
#  'The Watermelon Woman',
#  'The Truman Show',
#  'Hercules',
#  'Mulan',
#  'George of the Jungle',
#  'Sliding Doors',
#  'The Parent Trap',
#  'Anastasia',
#  'Practical Magic',
#  'As Good as It Gets',
#  'Pleasantville',
#  'Men in Black',
#  'The Mummy',
#  'Being John Malkovich',
#  'Good Will Hunting',
#  'Princess Mononoke',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Big Lebowski',
#  'Lock, Stock and Two Smoking Barrels',
#  '10 Cloverfield Lane',
#  'Prey',
#  '21 Jump Street',
#  'Brave',
#  'Looper',
#  'RED',
#  'Your Highness',
#  'Tarzan',
#  'X-Men',
#  'Get Him to the Greek',
#  'Kick-Ass',
#  'The Cabin in the Woods',
#  'The Twilight Saga: New Moon',
#  'Iron Man 2',
#  'Corpse Bride',
#  'Shrek',
#  'Men in Black II',
#  'Date Night',
#  'We Need to Talk About Kevin',
#  'Pariah',
#  "The World's End",
#  'This Is the End',
#  'Doctor Strange',
#  'Venom',
#  'Bad Teacher',
#  'Arthur',
#  'Ghostbusters',
#  'Easy A',
#  'The Twilight Saga: Eclipse',
#  'Despicable Me',
#  'Rushmore',
#  'Treasure Planet',
#  'SLC Punk',
#  'The Matrix',
#  'Fight Club',
#  'Iron Man 3',
#  'Seeking a Friend for the End of the World',
#  'How to Be Single',
#  'Passengers',
#  'Luca',
#  'Do Revenge',
#  'Monsters University',
#  'Fright Night',
#  'The Help',
#  'You Again',
#  'Inception',
#  'The Road to El Dorado',
#  'Big Daddy',
#  '10 Things I Hate About You',
#  'American Psycho',
#  'The Lorax',
#  'Mad Max: Fury Road',
#  'Rise of the Guardians',
#  "Bridget Jones's Baby",
#  'Deadpool',
#  'Suicide Squad',
#  'Baywatch',
#  'Mute',
#  'Bo Burnham: Inside',
#  "New Year's Eve",
#  '30 Minutes or Less',
#  "The King's Speech",
#  'Midnight in Paris',
#  'Crazy, Stupid, Love.',
#  'Just Go with It',
#  'Contagion',
#  "She's All That",
#  "Charlie's Angels",
#  'American Reunion',
#  'Jupiter Ascending',
#  'Warm Bodies',
#  'Beautiful Creatures',
#  'The Lego Movie',
#  'The Greatest Showman',
#  'The Big Short',
#  'Zombieland: Double Tap',
#  'Booksmart',
#  'The Legend of Pipi',
#  'The Art of Getting By',
#  'Kick-Ass 2',
#  'Friends with Benefits',
#  'Sinbad: Legend of the Seven Seas',
#  'Sleepy Hollow',
#  'American Pie',
#  'The Sixth Sense',
#  'The Lord of the Rings: The Return of the King',
#  'The Lord of the Rings: The Two Towers',
#  'Gladiator',
#  'Now You See Me',
#  'The Dictator',
#  'How to Train Your Dragon 2',
#  'Les Misérables',
#  'The Perks of Being a Wallflower',
#  'Snowpiercer',
#  "We're the Millers",
#  'The Man from U.N.C.L.E.',
#  'The DUFF',
#  "But I'm a Cheerleader",
#  '28 Days',
#  'Django Unchained',
#  'Paranormal Activity 3',
#  'Wreck-It Ralph',
#  'Moonrise Kingdom',
#  'This Is 40',
#  'Pitch Perfect',
#  'Guardians of the Galaxy',
#  'The To Do List',
#  'Carrie',
#  'That Awkward Moment',
#  'Barely Lethal',
#  "Miss Peregrine's Home for Peculiar Children",
#  'Black Panther',
#  'Dirty Grandpa',
#  'Blade Runner 2049',
#  'The Edge of Seventeen',
#  "The Hitman's Bodyguard",
#  'Atlantis: The Lost Empire',
#  'What Women Want',
#  'Miss Congeniality',
#  'Moulin Rouge!',
#  'Snatch',
#  'John Mulaney: New in Town',
#  'The Grand Budapest Hotel',
#  'About Time',
#  'Inside Out',
#  'Big Hero 6',
#  'The Imitation Game',
#  'Minions',
#  'Tammy',
#  'Final Girl',
#  'Spider-Man: Homecoming',
#  'Valerian and the City of a Thousand Planets',
#  'Jumanji: Welcome to the Jungle',
#  'Men in Black: International',
#  'Love and Monsters',
#  'Rat Race',
#  'The Princess Diaries',
#  'Legally Blonde',
#  'Wet Hot American Summer',
#  "Bridget Jones's Diary",
#  "Ocean's Eleven",
#  'Spirited Away',
#  'Avengers: Age of Ultron',
#  'The Family',
#  'The Heat',
#  'Hotel Transylvania 2',
#  'How to Train Your Dragon: The Hidden World',
#  'G.B.F.',
#  'Focus',
#  'The 5th Wave',
#  'Arrival',
#  'Keeping Up with the Joneses',
#  'Coco',
#  'The Cloverfield Paradox',
#  "Isn't It Romantic",
#  'Kill Bill: Vol. 1',
#  'Finding Nemo',
#  'X2',
#  'Sweet Home Alabama',
#  'Not Another Teen Movie',
#  'The Girl Next Door',
#  'Scooby-Doo',
#  'The Royal Tenenbaums',
#  'Catch Me If You Can',
#  'About a Boy',
#  'A Million Ways to Die in the West',
#  'Kingsman: The Secret Service',
#  'The Fault in Our Stars',
#  'The Interview',
#  'Alice Through the Looking Glass',
#  'Annihilation',
#  'Mike and Dave Need Wedding Dates',
#  'Bird Box',
#  'Game Night',
#  'Tag',
#  'Jojo Rabbit',
#  'Elf',
#  'Freaky Friday',
#  'The Incredibles',
#  'Bridget Jones: The Edge of Reason',
#  'Chicago',
#  'Shrek 2',
#  'Harry Potter and the Chamber of Secrets',
#  'Big Fish',
#  'The Ring',
#  'Love Actually',
#  'Underworld',
#  'Pride',
#  'John Wick',
#  'Fantastic Beasts and Where to Find Them',
#  'Room',
#  'Zootopia',
#  'Circle',
#  'Scoob!',
#  'Crazy Rich Asians',
#  'Sierra Burgess Is a Loser',
#  'A Beautiful Day in the Neighborhood',
#  'Soul',
#  'Encanto',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'The Cat Returns',
#  'Coraline',
#  'Scooby-Doo 2: Monsters Unleashed',
#  '13 Going on 30',
#  'The Stepford Wives',
#  'Waiting...',
#  'Over the Hedge',
#  "Something's Gotta Give",
#  "Howl's Moving Castle",
#  '50 First Dates',
#  'School of Rock',
#  'D.E.B.S.',
#  'What We Do in the Shadows',
#  'The Lobster',
#  'It Follows',
#  'Captain America: Civil War',
#  'Moana',
#  'Thor: Ragnarok',
#  'Little Women',
#  'Sing',
#  'Game Over, Man!',
#  'Inglourious Basterds',
#  'The Princess Diaries 2: Royal Engagement',
#  'Mean Girls',
#  'Miss Congeniality 2: Armed and Fabulous',
#  'Robots',
#  'Happy Feet',
#  'Napoleon Dynamite',
#  "The Hitchhiker's Guide to the Galaxy",
#  'Iron Man',
#  'Mr. & Mrs. Smith',
#  'Shaun of the Dead',
#  'Incredibles 2',
#  'The Martian',
#  'Power Rangers',
#  'La La Land',
#  'The Kissing Booth',
#  "To All the Boys I've Loved Before",
#  'Tangled',
#  'Where the Wild Things Are',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Wedding Crashers',
#  'Click',
#  'Monster House',
#  'Bee Movie',
#  'Underworld: Evolution',
#  'Guardians of the Galaxy Vol. 2',
#  'Avengers: Endgame',
#  'Avengers: Infinity War',
#  'Captain Marvel',
#  'The Lego Batman Movie',
#  'Free Fire',
#  'Baby Driver',
#  'The Love Witch',
#  'Okja',
#  'The Darkest Minds',
#  'Scott Pilgrim vs. the World',
#  'Get Smart',
#  'Fantastic Mr. Fox',
#  'Toy Story 3',
#  'Blades of Glory',
#  'The Descent',
#  'August Rush',
#  'The Curious Case of Benjamin Button',
#  'Hot Fuzz',
#  'Hard Candy',
#  'Marie Antoinette',
#  'V for Vendetta',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  'Shazam!',
#  'Wonder Woman',
#  'The Witch',
#  'The Founder',
#  'Frozen II',
#  'Paddington 2',
#  'Why Him?',
#  'Puss in Boots',
#  'The Babysitter',
#  'Ghostbusters: Afterlife',
#  'Extremely Loud & Incredibly Close',
#  "Lemony Snicket's A Series of Unfortunate Events",
#  "She's the Man",
#  'John Tucker Must Die',
#  'Juno',
#  'I Am Legend',
#  'Enchanted',
#  'Ant-Man',
#  'Spider-Man: Into the Spider-Verse',
#  'Kingsman: The Golden Circle',
#  'Lights Out',
#  'The Meg',
#  'Almost Adults',
#  'High Life',
#  'Satanic',
#  'The Death of Stalin',
#  'Good Time',
#  'Overlord',
#  'Klaus',
#  'In the Tall Grass',
#  'Avatar',
#  'The Disenchantment',
#  'Vertigo',
#  'Jurassic World: Fallen Kingdom',
#  'Ant-Man and the Wasp',
#  'John Mulaney: The Comeback Kid',
#  'Your Name.',
#  'The Favourite',
#  'Moonlight',
#  'Set It Up',
#  'Lady Bird',
#  'Isle of Dogs',
#  "Ocean's Eight",
#  'Get Out',
#  "Charlie's Angels",
#  'Raya and the Last Dragon',
#  'The Willoughbys',
#  'Deadpool 2',
#  'Train to Busan',
#  'Thoroughbreds',
#  'Call Me by Your Name',
#  'Bright',
#  'Ralph Breaks the Internet',
#  'The Little Hours',
#  'Damsel',
#  'Sorry to Bother You',
#  'The Ritual',
#  'Pokémon Detective Pikachu',
#  'Juliet, Naked',
#  'Apostle',
#  'The Suicide Squad',
#  'A Quiet Place',
#  'Slaughterhouse Rulez',
#  'Mamma Mia! Here We Go Again',
#  'Us',
#  'Code 8',
#  'Destination Wedding',
#  'I Am Mother',
#  'Candy Jar',
#  'Escape Room',
#  'Everything Everywhere All at Once',
#  'Tenet',
#  'Moxie',
#  'The Rocky Horror Picture Show',
#  'Carrie',
#  'Monty Python and the Holy Grail',
#  'Wonder Woman 1984',
#  'Once Upon a Time… in Hollywood',
#  'BlacKkKlansman',
#  'Blindspotting',
#  'Eighth Grade',
#  'Instant Family',
#  'Onward',
#  'Next Gen',
#  'Father of the Year',
#  'Over the Moon',
#  'Venom: Let There Be Carnage',
#  'Luck',
#  'Suspiria',
#  'Mamma Mia!',
#  'The Princess and the Frog',
#  'Forgetting Sarah Marshall',
#  'In Bruges',
#  'Airplane!',
#  'Grease',
#  'Life of Brian',
#  'Alien',
#  'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#  'Enola Holmes',
#  'The King',
#  'Red Notice',
#  'Jumanji: The Next Level',
#  'Bao',
#  "She's Out of My League",
#  'Cloudy with a Chance of Meatballs',
#  'The Girl Who Leapt Through Time',
#  'Fast Times at Ridgemont High',
#  'Tootsie',
#  'The Bucket List',
#  'The Thing',
#  'The Shining',
#  'E.T. the Extra-Terrestrial',
#  'Blade Runner',
#  'Hotel Transylvania',
#  'Interstellar',
#  'The Danish Girl',
#  'Turning Red',
#  'Bodies Bodies Bodies',
#  'John Mulaney: Kid Gorgeous at Radio City',
#  'The Gentlemen',
#  'Dolemite Is My Name',
#  '1917',
#  'Ghostbusters',
#  'The Blind Side',
#  'Clue',
#  'Sixteen Candles',
#  'Repo Man',
#  'Sunshine Cleaning',
#  'Ponyo',
#  'How to Train Your Dragon',
#  'The Breakfast Club',
#  'Trading Places',
#  'Back to the Future',
#  'Midsommar',
#  'The French Dispatch',
#  'Knives Out',
#  'The Farewell',
#  'Peninsula',
#  'Salt',
#  'Maurice',
#  'Pretty in Pink',
#  'Overboard',
#  'WALL·E',
#  "Ferris Bueller's Day Off",
#  'Tropic Thunder',
#  'The Witches of Eastwick',
#  'Beetlejuice',
#  'Big',
#  'Aliens',
#  'Dirty Dancing',
#  'Doctor Strange in the Multiverse of Madness',
#  'Eternals',
#  'Emma.',
#  'The Sea Beast',
#  'Palm Springs',
#  'Werewolves Within',
#  'Hanna',
#  'Sucker Punch',
#  '17 Again',
#  'Angus, Thongs and Perfect Snogging',
#  "St. Trinian's",
#  "You Don't Mess with the Zohan",
#  'Coming to America',
#  'My Neighbor Totoro',
#  '27 Dresses',
#  "Bill & Ted's Excellent Adventure",
#  'Do the Right Thing',
#  'A Fish Called Wanda',
#  'Die Hard',
#  'Dead Poets Society',
#  'Edward Scissorhands',
#  'The Wolf of Wall Street',
#  'Coffee & Kareem',
#  'The Empire Strikes Back',
#  'Jurassic Park',
#  'Star Wars',
#  'Ratatouille',
#  'Harry Potter and the Prisoner of Azkaban',
#  'The Princess Bride',
#  'The Devil Wears Prada',
#  'The Neon Demon',
#  'When Harry Met Sally...',
#  'Billy Elliot',
#  'The Nice Guys',
#  'Lemonade Mouth',
#  'Julie & Julia',
#  'Zoolander',
#  'A Little Princess',
#  'The Secret World of Arrietty',
#  'Blast from the Past',
#  'Who Framed Roger Rabbit',
#  'Crouching Tiger, Hidden Dragon',
#  'Cube',
#  "Don't Look Up",
#  'Bride Wars',
#  'How Do You Know',
#  'The Pacifier',
#  'Harry Potter and the Goblet of Fire',
#  'X-Men: Days of Future Past',
#  'X-Men: First Class',
#  'X-Men: Apocalypse',
#  "Assassin's Creed",
#  'Ice Age',
#  'Kung Fu Panda',
#  'Anchorman: The Legend of Ron Burgundy',
#  'Shark Tale',
#  'Kung Fu Panda 2',
#  'King Kong',
#  'Mars Attacks!',
#  'High Fidelity',
#  'Kung Fu Panda 3',
#  'Year One',
#  "Gulliver's Travels",
#  "Charlie's Angels: Full Throttle",
#  'Shanghai Noon',
#  'Mulan II',
#  'Tinker Bell',
#  'Secret of the Wings',
#  'Domino',
#  'Horrible Bosses',
#  'X-Men: The Last Stand',
#  'Catwoman',
#  'Gothika',
#  'Nanny McPhee',
#  'What a Girl Wants',
#  "St Trinian's 2: The Legend of Fritton's Gold",
#  'The Hobbit: An Unexpected Journey',
#  'Evan Almighty',
#  'Bewitched',
#  'Dinner for Schmucks',
#  'Horton Hears a Who!',
#  'Bruce Almighty',
#  'Eurovision Song Contest: The Story of Fire Saga',
#  'Sherlock Holmes: A Game of Shadows',
#  'Sherlock Holmes',
#  'The Little Prince',
#  'Cats & Dogs',
#  'Finding Dory',
#  'Murder on the Orient Express',
#  'Death Note',
#  'What If',
#  "Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Harry Potter and the Order of the Phoenix',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Harry Potter and the Half-Blood Prince',
#  '9',
#  'Back to the Future Part II',
#  'The Mask',
#  'Shrek the Third',
#  'Shrek Forever After',
#  "My Sister's Keeper",
#  'Annie',
#  'Scared Shrekless',
#  "What to Expect When You're Expecting",
#  'Grown Ups',
#  'Grown Ups 2',
#  'Idiocracy',
#  'Highlander',
#  'The Lost World: Jurassic Park',
#  "Bram Stoker's Dracula",
#  'Hook',
#  'Epic',
#  'Would You Rather',
#  'Charlie and the Chocolate Factory',
#  'Big Eyes',
#  'Hugo',
#  'Scream 2',
#  'Southland Tales',
#  "He's All That",
#  'Looney Tunes: Back in Action',
#  'Beverly Hills Chihuahua',
#  'The Smurfs',
#  'The Smurfs 2',
#  'Cheaper by the Dozen',
#  'The Pink Panther',
#  'Home',
#  'Cheaper by the Dozen 2',
#  "It's Complicated",
#  'Baby Mama',
#  'The Big Year',
#  'Dirty Rotten Scoundrels',
#  '¡Three Amigos!',
#  'Bedtime Stories',
#  'Mr. Deeds',
#  "That's My Boy",
#  'Coneheads',
#  'Thor',
#  'Captain America: The First Avenger',
#  'The Avengers',
#  'Captain America: The Winter Soldier',
#  'Thor: The Dark World',
#  "Ocean's Twelve",
#  'Die Hard 2',
#  'Nancy Drew',
#  'RED 2',
#  'Holes',
#  'The Tale of Despereaux',
#  'Assassination Nation',
#  'Black Mirror: White Christmas',
#  'Black Mirror: Bandersnatch',
#  'Vampire Gastelbrau',
#  'Afronauts',
#  'The Amazing Spider-Man',
#  'Double King',
#  'Fog',
#  'Cam',
#  'The Final Girls',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'Josie and the Pussycats',
#  'Troy',
#  'Percy Jackson: Sea of Monsters',
#  'Clash of the Titans',
#  'John Wick: Chapter 2',
#  "Legend of the Guardians: The Owls of Ga'Hoole",
#  'In a Heartbeat',
#  'Too Many Cooks',
#  'Hellboy',
#  'Lara Croft: Tomb Raider',
#  'Austin Powers in Goldmember',
#  'Austin Powers: International Man of Mystery',
#  'Austin Powers: The Spy Who Shagged Me',
#  'The Cat in the Hat',
#  'Chitty Chitty Bang Bang',
#  'I Care a Lot',
#  'Await Further Instructions',
#  'A.I. Artificial Intelligence',
#  'Jawbreaker',
#  'Down with Love',
#  'Mermaids',
#  'I Love You Phillip Morris',
#  'The Witches',
#  'Barbie as Rapunzel',
#  'Daddy Day Care',
#  'De-Lovely',
#  'Flushed Away',
#  'G-Force',
#  'Arthur Christmas',
#  'The Best Exotic Marigold Hotel',
#  'Wild Target',
#  'Hairspray',
#  'Gremlins',
#  'The Brady Bunch Movie',
#  'Alice in Wonderland',
#  'Chicken Little',
#  'Snow White and the Seven Dwarfs',
#  'Johnny English Reborn',
#  'Johnny English',
#  'Star Trek Into Darkness',
#  'Star Trek Beyond',
#  'The Maze Runner',
#  'Maze Runner: The Scorch Trials',
#  'Jurassic World',
#  'Oz the Great and Powerful',
#  'G.I. Jane',
#  'Monsters vs Aliens',
#  'Stuart Little',
#  'Tomorrowland',
#  'Slumdog Millionaire',
#  'The Oranges',
#  'Blackadder: Back & Forth',
#  'Blackadder: The Cavalier Years',
#  'Hop',
#  "Peter's Friends",
#  'Wallace & Gromit: The Curse of the Were-Rabbit',
#  'The Invention of Lying',
#  'The Change-Up',
#  'Arthur and the Invisibles',
#  'The Switch',
#  "Mr. Magorium's Wonder Emporium",
#  'This Is Where I Leave You',
#  'The Internship',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Night at the Museum',
#  'Two Weeks Notice',
#  'Just My Luck',
#  'Life As We Know It',
#  'This Means War',
#  'Into the Woods',
#  'Confessions of a Teenage Drama Queen',
#  'Mickey Blue Eyes',
#  'The Ugly Truth',
#  'Ghosts of Girlfriends Past',
#  'Definitely, Maybe',
#  'The Nanny Diaries',
#  "You've Got Mail",
#  'The Sisterhood of the Traveling Pants',
#  'Letters to Juliet',
#  'Meet the Fockers',
#  'Lilith & Eve',
#  'Rejected',
#  'Burrow',
#  'Sex & Violence with Machspeed',
#  'Greener Grass',
#  'Home Alone',
#  "Trick 'r Treat",
#  'The Croods',
#  "Charlotte's Web",
#  "Madagascar 3: Europe's Most Wanted",
#  'Madagascar: Escape 2 Africa',
#  'Garfield: A Tail of Two Kitties',
#  'Popstar: Never Stop Never Stopping',
#  'Ice Age: The Meltdown',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Blockers',
#  'Zathura: A Space Adventure',
#  'The Hunger Games',
#  'Pitch Perfect 2',
#  'I, Robot',
#  'Æon Flux',
#  'Pineapple Express',
#  'Marley & Me',
#  'Planet 51',
#  'Aladdin',
#  'Mrs. Doubtfire',
#  'One Hour Photo',
#  'Flubber',
#  'Bicentennial Man',
#  'Saving Face',
#  "I Don't Know How She Does It",
#  'What We Did on Our Holiday',
#  'The Decoy Bride',
#  'The Man Who Sued God',
#  'Pocahontas',
#  'Open Season',
#  'Bud Abbott and Lou Costello Meet Frankenstein',
#  'Divergent',
#  'Charlie St. Cloud',
#  'James Acaster: Cold Lasagne Hate Myself 1999',
#  'Nocturnal Animals',
#  'Bambi',
#  'Lilo & Stitch',
#  'Cinderella',
#  'The Little Mermaid',
#  'Fantasia',
#  'Lady and the Tramp',
#  'Mary Poppins',
#  'The Jungle Book',
#  'Peter Pan',
#  'James and the Giant Peach',
#  'Frozen',
#  'Monsters, Inc.',
#  "The Emperor's New Groove",
#  '101 Dalmatians',
#  'Hocus Pocus',
#  'Sing Street',
#  'Holidays',
#  'Downsizing',
#  'Harold & Kumar Go to White Castle',
#  "Mr. Popper's Penguins",
#  'Kate & Leopold',
#  'Star Trek',
#  'Son of the Mask',
#  'Minority Report',
#  'Safety Not Guaranteed',
#  'Housesitter',
#  'Christmas with the Kranks',
#  "My Babysitter's a Vampire",
#  'Radio Rebel',
#  '2012',
#  'Galaxy Quest',
#  'Imagine Me & You',
#  'Burn After Reading',
#  'Journey to the Center of the Earth',
#  'Inkheart',
#  'Stardust',
#  'Return of the Jedi',
#  'Toy Story 2',
#  'Raiders of the Lost Ark',
#  'Cars',
#  'Beauty and the Beast',
#  "A Bug's Life",
#  'Back to the Future Part III',
#  'The Wolverine',
#  'The Hunchback of Notre Dame',
#  'Gone Girl',
#  "The Sorcerer's Apprentice",
#  'R.I.P.D.',
#  'The House Bunny',
#  "What's Your Number?",
#  'Hereditary',
#  'The Angriest Man in Brooklyn',
#  'Old Dogs',
#  'Green Lantern',
#  'Season of the Witch',
#  'Burlesque',
#  'Junior',
#  'The Boy Who Cried Werewolf',
#  'Kindergarten Cop',
#  'Beethoven',
#  'Home Alone 2: Lost in New York',
#  'The Secret Garden',
#  'Billy Madison',
#  'A Goofy Movie',
#  'Casper',
#  'The Indian in the Cupboard',
#  'Matilda',
#  'Halloweentown',
#  'Scooby-Doo on Zombie Island',
#  'Chicken Run',
#  "Mom's Got a Date with a Vampire",
#  'How the Grinch Stole Christmas',
#  'Spy Kids',
#  'Dr. Dolittle 2',
#  'Osmosis Jones',
#  'Get a Clue',
#  'The Powerpuff Girls Movie',
#  'The Santa Clause 2',
#  'The Haunted Mansion',
#  'Garfield',
#  'The Polar Express',
#  "Mickey's Twice Upon a Christmas",
#  'Are We There Yet?',
#  'Madagascar',
#  'The Adventures of Sharkboy and Lavagirl',
#  'Sky High',
#  'Twitches',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'High School Musical',
#  'Wendy Wu: Homecoming Warrior',
#  'Scary Godmother: Halloween Spooktakular',
#  'The Santa Clause 3: The Escape Clause',
#  "Happily N'Ever After",
#  'Cinderella III: A Twist in Time',
#  'Bridge to Terabithia',
#  'Bratz: Fashion Pixiez',
#  'Meet the Robinsons',
#  'Are We Done Yet?',
#  'The Simpsons Movie',
#  'The Game Plan',
#  'Twitches Too',
#  'Roxy Hunter and the Mystery of the Moody Ghost',
#  'The Golden Compass',
#  'The Spiderwick Chronicles',
#  'Shorts',
#  "Nim's Island",
#  'Camp Rock',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Cheetah Girls: One World',
#  'Igor',
#  'Bolt',
#  'Hotel for Dogs',
#  'Princess Protection Program',
#  'Land of the Lost',
#  'Hannah Montana: The Movie',
#  'Race to Witch Mountain',
#  'Tooth Fairy',
#  'The Spy Next Door',
#  'Nanny McPhee and the Big Bang',
#  'Harriet the Spy: Blog Wars',
#  'Diary of a Wimpy Kid',
#  '16 Wishes',
#  'The Karate Kid',
#  'Flipped',
#  'I Am Number Four',
#  'Gnomeo & Juliet',
#  'Hoodwinked Too! Hood VS. Evil',
#  'Monster High: Fright On!',
#  'The Adventures of Tintin',
#  'Chronicle',
#  'Girl vs. Monster',
#  'Porco Rosso',
#  'Hotel Rwanda',
#  'What Happened to Monday',
#  'Be Kind Rewind',
#  'The Green Hornet',
#  'Krampus',
#  'Tau',
#  'Drag Me to Hell',
#  'K-PAX',
#  'Monster High: Why Do Ghouls Fall in Love?',
#  'Election',
#  'Meet Joe Black',
#  'Spider-Man',
#  'The Hunger Games: Catching Fire',
#  'Lake Mungo',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Hobbit: The Desolation of Smaug',
#  'Fallen',
#  'Bullet Train',
#  'The Adventures of Rocky & Bullwinkle',
#  'Ultraviolet',
#  'Event Horizon',
#  'An American Werewolf in London',
#  'Hellraiser',
#  "Weekend at Bernie's",
#  "Kiki's Delivery Service",
#  'Paddington',
#  "A Knight's Tale",
#  'Notting Hill',
#  'Willy Wonka & the Chocolate Factory',
#  'Bratz',
#  'Calendar Girls',
#  'The Age of Adaline',
#  'Mona Lisa Smile',
#  'Maid in Manhattan',
#  'L!fe Happens',
#  'The Host',
#  'Confessions of a Shopaholic',
#  'The Brothers Grimm',
#  'Red Riding Hood',
#  'Bo Burnham: What.',
#  'Uncut Gems',
#  'Gremlins 2: The New Batch',
#  'A Simple Favor',
#  'Sausage Party',
#  'Hair Love',
#  'Neighbors',
#  'Neighbors 2: Sorority Rising',
#  'Despicable Me 2',
#  'The Wolf of Snow Hollow',
#  'Maleficent',
#  'Cars 2',
#  'Kubo and the Two Strings',
#  'The Karate Kid',
#  'Labyrinth',
#  'Rio',
#  'Alvin and the Chipmunks',
#  "Surf's Up",
#  'Guns Akimbo',
#  'Good Morning, Vietnam',
#  'Lucy',
#  'The Wizard of Oz',
#  'Men in Black 3',
#  'The Girl with All the Gifts',
#  'The School for Good and Evil',
#  'Parasite',
#  'Saving Grace',
#  'Ghost Town',
#  'Keeping Mum',
#  'Ted',
#  'Vampire Academy',
#  'The Mortal Instruments: City of Bones',
#  'Peter Pan',
#  'How I Live Now',
#  'Emily the Criminal',
#  'Sky Captain and the World of Tomorrow',
#  'City of Ember',
#  'Independence Day: Resurgence',
#  'Frankenhooker',
#  'Descendants',
#  'Plan B',
#  "The 'Burbs",
#  'K-12',
#  'Brüno',
#  'Attack the Block',
#  'Ice Age: Continental Drift',
#  'The Boy in the Striped Pyjamas',
#  "Ender's Game",
#  'Boy',
#  'Accepted',
#  'Swordfish',
#  'The Secret of Moonacre',
#  'Ella Enchanted',
#  ...]

# %%
print(confirmed_movies[0].title)
# Out:
# <built-in method title of str object at 0x0000023735708C70>

# %%
zero_search = 0

tv_title = [] # to store list of titles with 0 results
tv_year = []  # to store list of release year with 0 results

for i,j in zip(title,released_year):
    response = search.movie(query=i, year=j)
    if (len(response['results'])) == 0:
        tv_title.append(i)
        tv_year.append(j)
        zero_search+= 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 7
#       4 tv_year = []  # to store list of release year with 0 results
#       6 for i,j in zip(title,released_year):
# ----> 7     response = search.movie(query=i, year=j)
#       8     if (len(response['results'])) == 0:
#       9         tv_title.append(i)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\tmdbsimple\search.py:112, in Search.movie(self, **kwargs)
#      90 """
#      91 Search for movies.
#      92
#    (...)
#     108     A dict respresentation of the JSON returned from the API.
#     109 """
#     110 path = self._get_path('movie')
# --> 112 response = self._GET(path, kwargs)
#     113 self._set_attrs_to_values(response)
#     114 return response
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\tmdbsimple\base.py:110, in TMDB._GET(self, path, params)
#     109 def _GET(self, path, params=None):
# --> 110     return self._request('GET', path, params=params)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\tmdbsimple\base.py:87, in TMDB._request(self, method, path, params, payload)
#      85 # Create a new request session if no global session is defined
#      86 if self.session is None:
# ---> 87     response = requests.request(
#      88         method,
#      89         url,
#      90         params=params,
#      91         data=json.dumps(payload) if payload else payload,
#      92         headers=self.headers, timeout=self.timeout
#      93     )
#      95 # Use the global requests session the user provided
#      96 else:
#      97     response = self.session.request(
#      98         method,
#      99         url,
#    (...)
#     102         headers=self.headers, timeout=self.timeout
#     103     )
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\The Baboon\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
tv_id = []

for i,j in zip(tv_title,tv_year):
    response = search.tv(query= i, year=j)
    for value in response['results']:
        if value['name'] == i:
            tv_id.append(value['id'])

# %%
for i in title:
    if i not in confirmed_movies and i not in tv_title:
        print(i)

# %%
movie_info=[]

for i in movie_id:
    movie = tmdb.Movies(i)
    response = movie.info()
    movie_info.append([movie.id, movie.title, movie.spoken_languages, movie.production_countries, movie.genres, 
                       movie.runtime, movie.release_date, movie.vote_count, movie.vote_average])
print(len(movie_info))
movie_info[:2]

# %%
tv_info=[]

for i in tv_id:
    tv = tmdb.TV(i)
    response = tv.info()
    tv_info.append([tv.id, tv.name, tv.origin_country, tv.genres, 
                   tv.spoken_languages, tv.episode_run_time,
                   tv.first_air_date, tv.number_of_seasons, 
                   tv.number_of_episodes, tv.vote_count, tv.vote_average])
tv_info

# %%
movie_df = pd.DataFrame(movie_info, columns =['ID', 'title', 'languages', 'prod_country', 'genres', 'runtime', 'releasedate', 'votecount', 'voteavg'])
movie_df.head()

# %%
# Convert it into dataframe
tv_df = pd.DataFrame(tv_info, columns =['ID', 'title', 'origin_country', 'genres', 'languages', 'eps_runtime', '1st_airdate', 'no_seasons', 'no_eps', 'vote_counts', 'vote_average'])
tv_df

# %%
movie_df.to_csv('watchedmovie.csv')
print("Exported movies successfully!")

tv_df.to_csv('watchedtv.csv')
print("Exported tv shows successfully!")
